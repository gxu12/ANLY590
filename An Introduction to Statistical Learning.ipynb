# %% [markdown]
# # Chapter 2: Statistical Learning

# %%
# Measuring the Quality of Fit

# %% [markdown]
# In regression, the most commonly-used measure is:
#
# ![Screen%20Shot%202020-09-24%20at%205.28.52%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%205.28.52%20PM.png)

# %%
# The Bias-Variance Trade-Off

# %% [markdown]
# The expected test MSE, for agiven value x0 can always be into the sum of three fundamental quantities:
#
# 1. The variance of f(x0)
# 2. The squared bias of f(x0)
# 3. The variance of the error terms
#
# ![Screen%20Shot%202020-09-24%20at%205.35.33%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%205.35.33%20PM.png)
#
# **Variance** refers to the amount by which f would change if we estimate it using a different training dataset.
#
# **bias** refers to the error that is introduced by approximating a real-life problem.
#
# As we use use more flexible methods, the **variance** will increase, and the **bias** will decrease.

# %%
# The Classification Setting

# %%
# 1. The Bayes Classifier

# %% [markdown]
# we should assign a observation to class j for which
#
# ![Screen%20Shot%202020-09-24%20at%205.43.21%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%205.43.21%20PM.png)
#
# is largest.

# %%
# 2. K-Nearset Neighbors

# %% [markdown]
# Sometimes, we do not know the conditional distribution of Y given X.
#
# Given a positive integer K and a test observation x0,
#
# the KNN classifier first identifier the K points in the training data that are closest to x0, and then estimates the conditional probability for class j as the fraction of points in N0 whose response values equal to j:
#
# ![Screen%20Shot%202020-09-24%20at%205.46.42%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%205.46.42%20PM.png)
#
# Finally KNN applies Bayes rule and classifiers the test observation x0

# %%
# Exercise:

# %% [markdown]
# Question 1:
#
# ![Screen%20Shot%202020-09-24%20at%205.50.10%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%205.50.10%20PM.png)
#
# Ans:
#
# 1. Better
# 2. Worse
# 3. Better, flexible method is more suitable in non-linear situations;
# 4. Worse, make flexible method overfit

# %% [markdown]
# Question 5:
#
# ![Screen%20Shot%202020-09-24%20at%205.53.34%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%205.53.34%20PM.png)
#
# Ans:
#
# Less Flexible:
#
# (+) gives better result with few observations
#
# (+) easily understand
#
# (+) fewer parameters
#
# (-) perform poorly if non-linear relationship
#
# More Flexible:
#
# (+) perform well if non-linear relationship
#
# (-) overfit

# %% [markdown]
# Question 6:
#
# ![Screen%20Shot%202020-09-24%20at%206.02.03%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%206.02.03%20PM.png)
#
# Ans:
#
# A parametric approach simplifies the problem of estimating the best fit to the training data f(x) by making some assumptions about the functional form of f(x), this reduces the problem to estimating the parameters of the model. A non-parametric approach make no such assumptions and so f(x) can take any arbitrary shape.
#
# The advantage of the parametric approach is that it simplifies the problem of estimating f(x) because it is easier to estimate paramters than an arbitrary function. The disadvantage of this approach is that the assumed form of the function f(X) could limit the degree of accuracy with which the model can fit the training data. If too many parameters are used, in an attempt to increase the models flexibility, then overfitting can occur – meaning that the model begins to fit noise in the training data that is not representive of unseen observations.

# %% [markdown]
# # Chapter 3: Linear Regression
